# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
clean_data_df = pd.read_csv("cleaned_data.csv",index_col="Unnamed: 0")
clean_data_df.head()
# Out:
#     city_development_index  training_hours  target  gender_Female  \
# 1                    0.776              47     0.0            0.0
# 4                    0.767               8     0.0            0.0
# 7                    0.762              18     1.0            0.0
# 8                    0.920              46     1.0            0.0
# 11                   0.920             108     0.0            0.0
#
#     gender_Male  gender_Other  relevent_experience_Has relevent experience  \
# 1           1.0           0.0                                          1.0
# 4           1.0           0.0                                          1.0
# 7           1.0           0.0                                          1.0
# 8           1.0           0.0                                          1.0
# 11          1.0           0.0                                          1.0
#
#     relevent_experience_No relevent experience  \
# 1                                          0.0
# 4                                          0.0
# 7                                          0.0
# 8                                          0.0
# 11                                         0.0
#
#     enrolled_university_Full time course  \
# 1                                    0.0
# 4                                    0.0
# 7                                    0.0
# 8                                    0.0
# 11                                   0.0
#
#     enrolled_university_Part time course  ...  company_type_NGO  \
# 1                                    0.0  ...               0.0
# 4                                    0.0  ...               0.0
# 7                                    0.0  ...               0.0
# 8                                    0.0  ...               0.0
# 11                                   0.0  ...               0.0
#
#     company_type_Other  company_type_Public Sector  company_type_Pvt Ltd  \
# 1                  0.0                         0.0                   0.0
# 4                  0.0                         0.0                   1.0
# 7                  0.0                         0.0                   1.0
# 8                  0.0                         0.0                   1.0
# 11                 0.0                         0.0                   1.0
#
#     last_new_job_1  last_new_job_2  last_new_job_3  last_new_job_4  \
# 1              0.0             0.0             0.0             1.0
# 4              1.0             0.0             0.0             0.0
# 7              1.0             0.0             0.0             0.0
# 8              0.0             1.0             0.0             0.0
# 11             0.0             0.0             1.0             0.0
#
#     last_new_job_>4  last_new_job_never
# 1               0.0                 0.0
# 4               0.0                 0.0
# 7               0.0                 0.0
# 8               0.0                 0.0
# 11              0.0                 0.0
#
# [5 rows x 62 columns]

# %%
clean_data_df.dtypes
# Out:
# city_development_index    float64
# training_hours              int64
# target                    float64
# gender_Female             float64
# gender_Male               float64
#                            ...
# last_new_job_2            float64
# last_new_job_3            float64
# last_new_job_4            float64
# last_new_job_>4           float64
# last_new_job_never        float64
# Length: 62, dtype: object

# %%
# Split our preprocessed data into our features and target arrays
y = clean_data_df["target"].values
X = clean_data_df.drop(["target"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 80)                4960
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                2430
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 7,421
# Trainable params: 7,421
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.5171 - accuracy: 0.8260
# Epoch 2/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4445 - accuracy: 0.8394
# Epoch 3/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4310 - accuracy: 0.8434
# Epoch 4/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4446 - accuracy: 0.8315
# Epoch 5/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4597 - accuracy: 0.8311
# Epoch 6/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4072 - accuracy: 0.8508
# Epoch 7/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4613 - accuracy: 0.8303
# Epoch 8/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4098 - accuracy: 0.8424
# Epoch 9/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3984 - accuracy: 0.8500
# Epoch 10/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4042 - accuracy: 0.8499
# Epoch 11/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3974 - accuracy: 0.8453
# Epoch 12/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4047 - accuracy: 0.8415
# Epoch 13/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3901 - accuracy: 0.8513
# Epoch 14/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3910 - accuracy: 0.8494
# Epoch 15/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3805 - accuracy: 0.8545
# Epoch 16/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3792 - accuracy: 0.8552
# Epoch 17/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3816 - accuracy: 0.8487
# Epoch 18/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3795 - accuracy: 0.8504
# Epoch 19/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3555 - accuracy: 0.8564
# Epoch 20/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8657
# Epoch 21/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3732 - accuracy: 0.8544
# Epoch 22/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3560 - accuracy: 0.8582
# Epoch 23/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3536 - accuracy: 0.8639
# Epoch 24/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3357 - accuracy: 0.8648
# Epoch 25/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3552 - accuracy: 0.8585
# Epoch 26/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3606 - accuracy: 0.8608
# Epoch 27/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3324 - accuracy: 0.8735
# Epoch 28/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3205 - accuracy: 0.8728
# Epoch 29/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3064 - accuracy: 0.8769
# Epoch 30/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3220 - accuracy: 0.8747
# Epoch 31/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2960 - accuracy: 0.8811
# Epoch 32/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3362 - accuracy: 0.8714
# Epoch 33/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3211 - accuracy: 0.8681
# Epoch 34/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3214 - accuracy: 0.8698
# Epoch 35/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3083 - accuracy: 0.8754
# Epoch 36/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3064 - accuracy: 0.8787
# Epoch 37/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2998 - accuracy: 0.8835
# Epoch 38/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3054 - accuracy: 0.8813
# Epoch 39/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3043 - accuracy: 0.8819
# Epoch 40/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3120 - accuracy: 0.8753
# Epoch 41/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2988 - accuracy: 0.8675
# Epoch 42/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3229 - accuracy: 0.8809
# Epoch 43/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2833 - accuracy: 0.8862
# Epoch 44/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2909 - accuracy: 0.8862
# Epoch 45/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2816 - accuracy: 0.8913
# Epoch 46/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2854 - accuracy: 0.8873
# Epoch 47/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2796 - accuracy: 0.8868
# Epoch 48/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3030 - accuracy: 0.8755
# Epoch 49/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2781 - accuracy: 0.8936
# Epoch 50/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2955 - accuracy: 0.8893
# Epoch 51/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2782 - accuracy: 0.8835
# Epoch 52/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2753 - accuracy: 0.8937
# Epoch 53/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2819 - accuracy: 0.8914
# Epoch 54/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2747 - accuracy: 0.8945
# Epoch 55/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2676 - accuracy: 0.8887
# Epoch 56/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2550 - accuracy: 0.8996
# Epoch 57/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2654 - accuracy: 0.8932
# Epoch 58/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2527 - accuracy: 0.9018
# Epoch 59/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2640 - accuracy: 0.8979
# Epoch 60/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2580 - accuracy: 0.8991
# Epoch 61/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3004 - accuracy: 0.8826
# Epoch 62/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2551 - accuracy: 0.8951
# Epoch 63/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2570 - accuracy: 0.8935
# Epoch 64/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2630 - accuracy: 0.8985
# Epoch 65/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2546 - accuracy: 0.8964
# Epoch 66/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2522 - accuracy: 0.9016
# Epoch 67/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2530 - accuracy: 0.9009
# Epoch 68/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2676 - accuracy: 0.8929
# Epoch 69/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2522 - accuracy: 0.8964
# Epoch 70/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2313 - accuracy: 0.9114
# Epoch 71/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2388 - accuracy: 0.9049
# Epoch 72/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2506 - accuracy: 0.9045
# Epoch 73/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2493 - accuracy: 0.8929
# Epoch 74/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2574 - accuracy: 0.9044
# Epoch 75/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2351 - accuracy: 0.9129
# Epoch 76/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2465 - accuracy: 0.9008
# Epoch 77/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2347 - accuracy: 0.9040
# Epoch 78/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2335 - accuracy: 0.8985
# Epoch 79/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2400 - accuracy: 0.9151
# Epoch 80/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2267 - accuracy: 0.9125
# Epoch 81/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2332 - accuracy: 0.9025
# Epoch 82/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2176 - accuracy: 0.9190
# Epoch 83/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2289 - accuracy: 0.9080
# Epoch 84/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2226 - accuracy: 0.9178
# Epoch 85/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2179 - accuracy: 0.9136
# Epoch 86/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2325 - accuracy: 0.9096
# Epoch 87/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2162 - accuracy: 0.9145
# Epoch 88/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2322 - accuracy: 0.9014
# Epoch 89/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2452 - accuracy: 0.9020
# Epoch 90/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2025 - accuracy: 0.9222
# Epoch 91/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2127 - accuracy: 0.9153
# Epoch 92/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2261 - accuracy: 0.9130
# Epoch 93/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2160 - accuracy: 0.9174
# Epoch 94/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2139 - accuracy: 0.9106
# Epoch 95/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2260 - accuracy: 0.9127
# Epoch 96/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2082 - accuracy: 0.9145
# Epoch 97/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2249 - accuracy: 0.9043
# Epoch 98/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2112 - accuracy: 0.9170
# Epoch 99/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2142 - accuracy: 0.9111
# Epoch 100/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2159 - accuracy: 0.9108

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 33/33 - 0s - loss: 0.9516 - accuracy: 0.8152
# Loss: 0.9516273736953735, Accuracy: 0.8152381181716919
