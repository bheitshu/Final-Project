# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import tensorflow as tf

#  Import and read the charity_data.csv.
# import pandas as pd 
# clean_data_df = pd.read_csv("cleaned_data.csv",index_col="Unnamed: 0")
# clean_data_df.head()

import psycopg2
import pandas as pds
from sqlalchemy import create_engine

conn = psycopg2.connect(dbname='postgres', user='postgres', password='bootcamp', host='localhost', port='5432')
clean_data_df = pds.read_sql("select * from \"final_data\"", conn);
clean_data_df.set_index('index')
# Out:
#        training_hours  target  gender_Female  gender_Male  gender_Other  \
# index
# 1                  47       0              0            1             0
# 4                   8       0              0            1             0
# 7                  18       1              0            1             0
# 8                  46       1              0            1             0
# 11                108       0              0            1             0
# ...               ...     ...            ...          ...           ...
# 8938               15       0              0            1             0
# 8940               13       0              0            1             0
# 8943               37       0              0            1             0
# 8950               66       0              0            1             0
# 8952               15       0              1            0             0
#
#        relevent_experience_Has relevent experience  \
# index
# 1                                                1
# 4                                                1
# 7                                                1
# 8                                                1
# 11                                               1
# ...                                            ...
# 8938                                             1
# 8940                                             1
# 8943                                             1
# 8950                                             0
# 8952                                             1
#
#        relevent_experience_No relevent experience  \
# index
# 1                                               0
# 4                                               0
# 7                                               0
# 8                                               0
# 11                                              0
# ...                                           ...
# 8938                                            0
# 8940                                            0
# 8943                                            0
# 8950                                            1
# 8952                                            0
#
#        enrolled_university_Full time course  \
# index
# 1                                         0
# 4                                         0
# 7                                         0
# 8                                         0
# 11                                        0
# ...                                     ...
# 8938                                      0
# 8940                                      0
# 8943                                      0
# 8950                                      1
# 8952                                      0
#
#        enrolled_university_Part time course  \
# index
# 1                                         0
# 4                                         0
# 7                                         0
# 8                                         0
# 11                                        0
# ...                                     ...
# 8938                                      0
# 8940                                      0
# 8943                                      0
# 8950                                      0
# 8952                                      0
#
#        enrolled_university_no_enrollment  ...  company_size_500-999  \
# index                                     ...
# 1                                      1  ...                     0
# 4                                      1  ...                     0
# 7                                      1  ...                     0
# 8                                      1  ...                     0
# 11                                     1  ...                     0
# ...                                  ...  ...                   ...
# 8938                                   1  ...                     0
# 8940                                   1  ...                     0
# 8943                                   1  ...                     0
# 8950                                   0  ...                     0
# 8952                                   1  ...                     0
#
#        company_size_1000-4999  company_size_5000-9999  company_size_10000+  \
# index
# 1                           0                       0                    0
# 4                           0                       1                    0
# 7                           0                       0                    0
# 8                           0                       0                    0
# 11                          0                       0                    0
# ...                       ...                     ...                  ...
# 8938                        0                       0                    0
# 8940                        0                       0                    0
# 8943                        0                       0                    0
# 8950                        0                       0                    0
# 8952                        0                       0                    0
#
#        company_type_Early Stage Startup  company_type_Funded Startup  \
# index
# 1                                     0                            1
# 4                                     0                            0
# 7                                     0                            0
# 8                                     0                            0
# 11                                    0                            0
# ...                                 ...                          ...
# 8938                                  0                            0
# 8940                                  0                            0
# 8943                                  0                            0
# 8950                                  0                            0
# 8952                                  0                            0
#
#        company_type_NGO  company_type_Public Sector  company_type_Pvt Ltd  \
# index
# 1                     0                           0                     0
# 4                     0                           0                     1
# 7                     0                           0                     1
# 8                     0                           0                     1
# 11                    0                           0                     1
# ...                 ...                         ...                   ...
# 8938                  0                           0                     1
# 8940                  0                           0                     1
# 8943                  0                           0                     1
# 8950                  0                           0                     1
# 8952                  0                           1                     0
#
#        company_type_Other
# index
# 1                       0
# 4                       0
# 7                       0
# 8                       0
# 11                      0
# ...                   ...
# 8938                    0
# 8940                    0
# 8943                    0
# 8950                    0
# 8952                    0
#
# [4197 rows x 62 columns]

# %%
clean_data_df=clean_data_df.drop(['index'], axis=1)
clean_data_df.dtypes
# Out:
# training_hours                 int64
# target                         int64
# gender_Female                  int64
# gender_Male                    int64
# gender_Other                   int64
#                                ...
# company_type_Funded Startup    int64
# company_type_NGO               int64
# company_type_Public Sector     int64
# company_type_Pvt Ltd           int64
# company_type_Other             int64
# Length: 62, dtype: object

# %%
# Split our preprocessed data into our features and target arrays
y = clean_data_df["target"].values
X = clean_data_df.drop(["target"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 80)                4960
# _________________________________________________________________
# dense_4 (Dense)              (None, 30)                2430
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 7,421
# Trainable params: 7,421
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 99/99 [==============================] - 1s 1ms/step - loss: 0.8151 - accuracy: 0.7053
# Epoch 2/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4535 - accuracy: 0.8357
# Epoch 3/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4220 - accuracy: 0.8493
# Epoch 4/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4204 - accuracy: 0.8479
# Epoch 5/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4298 - accuracy: 0.8436
# Epoch 6/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4197 - accuracy: 0.8481
# Epoch 7/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4175 - accuracy: 0.8482
# Epoch 8/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4022 - accuracy: 0.8522
# Epoch 9/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4112 - accuracy: 0.8431
# Epoch 10/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4108 - accuracy: 0.8456
# Epoch 11/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4080 - accuracy: 0.8452
# Epoch 12/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4096 - accuracy: 0.8449
# Epoch 13/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3985 - accuracy: 0.8460
# Epoch 14/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3954 - accuracy: 0.8468
# Epoch 15/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.4081 - accuracy: 0.8390
# Epoch 16/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3952 - accuracy: 0.8499
# Epoch 17/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3869 - accuracy: 0.8479
# Epoch 18/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3615 - accuracy: 0.8640
# Epoch 19/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3794 - accuracy: 0.8444
# Epoch 20/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3580 - accuracy: 0.8634
# Epoch 21/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3631 - accuracy: 0.8561
# Epoch 22/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3539 - accuracy: 0.8554
# Epoch 23/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3516 - accuracy: 0.8664
# Epoch 24/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3423 - accuracy: 0.8640
# Epoch 25/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3698 - accuracy: 0.8504
# Epoch 26/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3494 - accuracy: 0.8607
# Epoch 27/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3380 - accuracy: 0.8656
# Epoch 28/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.8623
# Epoch 29/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3503 - accuracy: 0.8582
# Epoch 30/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3300 - accuracy: 0.8647
# Epoch 31/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3229 - accuracy: 0.8697
# Epoch 32/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3210 - accuracy: 0.8756
# Epoch 33/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3413 - accuracy: 0.8592
# Epoch 34/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3225 - accuracy: 0.8737
# Epoch 35/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3321 - accuracy: 0.8624
# Epoch 36/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3308 - accuracy: 0.8658
# Epoch 37/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3177 - accuracy: 0.8718
# Epoch 38/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3364 - accuracy: 0.8610
# Epoch 39/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3140 - accuracy: 0.8791
# Epoch 40/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2969 - accuracy: 0.8875
# Epoch 41/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3391 - accuracy: 0.8618
# Epoch 42/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3125 - accuracy: 0.8802
# Epoch 43/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3051 - accuracy: 0.8771
# Epoch 44/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2943 - accuracy: 0.8836
# Epoch 45/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2914 - accuracy: 0.8823
# Epoch 46/100
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3079 - accuracy: 0.8748
# Epoch 47/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3041 - accuracy: 0.8820
# Epoch 48/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2873 - accuracy: 0.8828
# Epoch 49/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2925 - accuracy: 0.8835
# Epoch 50/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2736 - accuracy: 0.9027
# Epoch 51/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2639 - accuracy: 0.8991
# Epoch 52/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2764 - accuracy: 0.8769
# Epoch 53/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2581 - accuracy: 0.8969
# Epoch 54/100
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2809 - accuracy: 0.8886
# Epoch 55/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2727 - accuracy: 0.8943
# Epoch 56/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2803 - accuracy: 0.8878
# Epoch 57/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2505 - accuracy: 0.9015
# Epoch 58/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2637 - accuracy: 0.8946
# Epoch 59/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2788 - accuracy: 0.8955
# Epoch 60/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2615 - accuracy: 0.8977
# Epoch 61/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.3065 - accuracy: 0.8815
# Epoch 62/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2731 - accuracy: 0.8842
# Epoch 63/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2489 - accuracy: 0.9009
# Epoch 64/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2771 - accuracy: 0.8883
# Epoch 65/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2630 - accuracy: 0.8948
# Epoch 66/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2672 - accuracy: 0.8983
# Epoch 67/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2385 - accuracy: 0.9033
# Epoch 68/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2619 - accuracy: 0.8898
# Epoch 69/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2672 - accuracy: 0.8956
# Epoch 70/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2440 - accuracy: 0.9033
# Epoch 71/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2658 - accuracy: 0.8873
# Epoch 72/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2327 - accuracy: 0.9066
# Epoch 73/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2470 - accuracy: 0.9034
# Epoch 74/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2407 - accuracy: 0.9085
# Epoch 75/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2504 - accuracy: 0.8997
# Epoch 76/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2585 - accuracy: 0.8992
# Epoch 77/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2290 - accuracy: 0.9052: 0s - loss: 0.2169 - accuracy: 0.
# Epoch 78/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2267 - accuracy: 0.9125
# Epoch 79/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2303 - accuracy: 0.9149
# Epoch 80/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2468 - accuracy: 0.8954
# Epoch 81/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2399 - accuracy: 0.8984
# Epoch 82/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2425 - accuracy: 0.8980
# Epoch 83/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2388 - accuracy: 0.9066
# Epoch 84/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2327 - accuracy: 0.9050
# Epoch 85/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2500 - accuracy: 0.8963
# Epoch 86/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2108 - accuracy: 0.9201
# Epoch 87/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2278 - accuracy: 0.9100
# Epoch 88/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2311 - accuracy: 0.9117
# Epoch 89/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2388 - accuracy: 0.9064
# Epoch 90/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2195 - accuracy: 0.9154
# Epoch 91/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2151 - accuracy: 0.9156
# Epoch 92/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2146 - accuracy: 0.9194
# Epoch 93/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2366 - accuracy: 0.9030
# Epoch 94/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2436 - accuracy: 0.9019
# Epoch 95/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2226 - accuracy: 0.9087
# Epoch 96/100
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2362 - accuracy: 0.9113
# Epoch 97/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2133 - accuracy: 0.9127
# Epoch 98/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2024 - accuracy: 0.9231
# Epoch 99/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2124 - accuracy: 0.9176
# Epoch 100/100
# 99/99 [==============================] - 0s 1ms/step - loss: 0.2295 - accuracy: 0.9096

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 33/33 - 0s - loss: 0.9200 - accuracy: 0.8095
# Loss: 0.9199539422988892, Accuracy: 0.8095238208770752
