# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
clean_data_df = pd.read_csv("cleaned_data.csv",index_col="Unnamed: 0")
clean_data_df
# Out:
#       city_development_index  training_hours  target  gender_Female  \
# 1                      0.776              47     0.0            0.0
# 4                      0.767               8     0.0            0.0
# 7                      0.762              18     1.0            0.0
# 8                      0.920              46     1.0            0.0
# 11                     0.920             108     0.0            0.0
# ...                      ...             ...     ...            ...
# 8938                   0.926              15     0.0            0.0
# 8940                   0.624              13     0.0            0.0
# 8943                   0.890              37     0.0            0.0
# 8950                   0.939              66     0.0            0.0
# 8952                   0.920              15     0.0            1.0
#
#       gender_Male  gender_Other  relevent_experience_Has relevent experience  \
# 1             1.0           0.0                                          1.0
# 4             1.0           0.0                                          1.0
# 7             1.0           0.0                                          1.0
# 8             1.0           0.0                                          1.0
# 11            1.0           0.0                                          1.0
# ...           ...           ...                                          ...
# 8938          1.0           0.0                                          1.0
# 8940          1.0           0.0                                          1.0
# 8943          1.0           0.0                                          1.0
# 8950          1.0           0.0                                          0.0
# 8952          0.0           0.0                                          1.0
#
#       relevent_experience_No relevent experience  \
# 1                                            0.0
# 4                                            0.0
# 7                                            0.0
# 8                                            0.0
# 11                                           0.0
# ...                                          ...
# 8938                                         0.0
# 8940                                         0.0
# 8943                                         0.0
# 8950                                         1.0
# 8952                                         0.0
#
#       enrolled_university_Full time course  \
# 1                                      0.0
# 4                                      0.0
# 7                                      0.0
# 8                                      0.0
# 11                                     0.0
# ...                                    ...
# 8938                                   0.0
# 8940                                   0.0
# 8943                                   0.0
# 8950                                   1.0
# 8952                                   0.0
#
#       enrolled_university_Part time course  ...  company_type_NGO  \
# 1                                      0.0  ...               0.0
# 4                                      0.0  ...               0.0
# 7                                      0.0  ...               0.0
# 8                                      0.0  ...               0.0
# 11                                     0.0  ...               0.0
# ...                                    ...  ...               ...
# 8938                                   0.0  ...               0.0
# 8940                                   0.0  ...               0.0
# 8943                                   0.0  ...               0.0
# 8950                                   0.0  ...               0.0
# 8952                                   0.0  ...               0.0
#
#       company_type_Other  company_type_Public Sector  company_type_Pvt Ltd  \
# 1                    0.0                         0.0                   0.0
# 4                    0.0                         0.0                   1.0
# 7                    0.0                         0.0                   1.0
# 8                    0.0                         0.0                   1.0
# 11                   0.0                         0.0                   1.0
# ...                  ...                         ...                   ...
# 8938                 0.0                         0.0                   1.0
# 8940                 0.0                         0.0                   1.0
# 8943                 0.0                         0.0                   1.0
# 8950                 0.0                         0.0                   1.0
# 8952                 0.0                         1.0                   0.0
#
#       last_new_job_1  last_new_job_2  last_new_job_3  last_new_job_4  \
# 1                0.0             0.0             0.0             1.0
# 4                1.0             0.0             0.0             0.0
# 7                1.0             0.0             0.0             0.0
# 8                0.0             1.0             0.0             0.0
# 11               0.0             0.0             1.0             0.0
# ...              ...             ...             ...             ...
# 8938             0.0             0.0             1.0             0.0
# 8940             0.0             0.0             1.0             0.0
# 8943             0.0             0.0             0.0             0.0
# 8950             1.0             0.0             0.0             0.0
# 8952             0.0             0.0             1.0             0.0
#
#       last_new_job_>4  last_new_job_never
# 1                 0.0                 0.0
# 4                 0.0                 0.0
# 7                 0.0                 0.0
# 8                 0.0                 0.0
# 11                0.0                 0.0
# ...               ...                 ...
# 8938              0.0                 0.0
# 8940              0.0                 0.0
# 8943              1.0                 0.0
# 8950              0.0                 0.0
# 8952              0.0                 0.0
#
# [4197 rows x 62 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = clean_data_df["target"].values
X = clean_data_df.drop(["target"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
